# %% [markdown]
# <a href="https://colab.research.google.com/github/iampundir/Covid-Analysis/blob/master/_Shubham_pundir_covid19_assign_c200025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
case_data=pd.read_csv(r"covid_19_india.csv")

# %%
case_data.head(20)
# Out:
#     Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     1  30/01/20  6:00 PM               Kerala                       1
# 1     2  31/01/20  6:00 PM               Kerala                       1
# 2     3  01/02/20  6:00 PM               Kerala                       2
# 3     4  02/02/20  6:00 PM               Kerala                       3
# 4     5  03/02/20  6:00 PM               Kerala                       3
# 5     6  04/02/20  6:00 PM               Kerala                       3
# 6     7  05/02/20  6:00 PM               Kerala                       3
# 7     8  06/02/20  6:00 PM               Kerala                       3
# 8     9  07/02/20  6:00 PM               Kerala                       3
# 9    10  08/02/20  6:00 PM               Kerala                       3
# 10   11  09/02/20  6:00 PM               Kerala                       3
# 11   12  10/02/20  6:00 PM               Kerala                       3
# ...

# %%
case_data.dtypes
# Out:
# Sno                          int64
# Date                        object
# Time                        object
# State/UnionTerritory        object
# ConfirmedIndianNational     object
# ConfirmedForeignNational    object
# Cured                        int64
# Deaths                       int64
# Confirmed                    int64
# dtype: object

# %%
case_data["Date"]=pd.to_datetime(case_data["Date"],format="%d/%m/%y")

# %%
case_data.describe()
# Out:
#                Sno         Cured       Deaths     Confirmed
# count  2919.000000   2919.000000  2919.000000   2919.000000
# mean   1460.000000    847.454950    60.484755   2048.870161
# std     842.787043   3067.658905   246.276168   7038.064300
# min       1.000000      0.000000     0.000000      0.000000
# 25%     730.500000      1.000000     0.000000     12.000000
# 50%    1460.000000     24.000000     1.000000     86.000000
# 75%    2189.500000    320.500000    16.000000   1141.000000
# max    2919.000000  44517.000000  3438.000000  94041.000000

# %%
case_data["Date"].describe
# Out:
# <bound method NDFrame.describe of 0      2020-01-30
# 1      2020-01-31
# 2      2020-02-01
# 3      2020-02-02
# 4      2020-02-03
#           ...
# 2914   2020-06-11
# 2915   2020-06-11
# 2916   2020-06-11
# 2917   2020-06-11
# 2918   2020-06-11
# Name: Date, Length: 2919, dtype: datetime64[ns]>

# %%
case_data["State/UnionTerritory"].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya', 'Dadar Nagar Haveli',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu'],
#       dtype=object)

# %%
case_data["ConfirmedIndianNational"].unique()
# Out:
# array(['1', '2', '3', '0', '6', '7', '8', '9', '4', '15', '5', '17', '10',
#        '11', '19', '14', '22', '32', '12', '23', '24', '36', '25', '39',
#        '44', '18', '16', '26', '49', '33', '60', '13', '28', '45', '64',
#        '21', '29', '71', '30', '37', '87', '86', '41', '101', '125', '34',
#        '35', '42', '55', '110', '20', '121', '40', '129', '127', '38',
#        '168', '177', '52', '46', '54', '-'], dtype=object)

# %%
case_data[case_data["ConfirmedIndianNational"]=="-"]
# Out:
#        Sno       Date     Time              State/UnionTerritory  \
# 446    447 2020-03-29  7:30 PM                    Andhra Pradesh
# 447    448 2020-03-29  7:30 PM       Andaman and Nicobar Islands
# 448    449 2020-03-29  7:30 PM                             Bihar
# 449    450 2020-03-29  7:30 PM                        Chandigarh
# 450    451 2020-03-29  7:30 PM                      Chhattisgarh
# ...    ...        ...      ...                               ...
# 2914  2915 2020-06-11  8:00 AM                           Tripura
# 2915  2916 2020-06-11  8:00 AM                       Uttarakhand
# 2916  2917 2020-06-11  8:00 AM                     Uttar Pradesh
# 2917  2918 2020-06-11  8:00 AM                       West Bengal
# 2918  2919 2020-06-11  8:00 AM  Cases being reassigned to states
#
#      ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 446                        -                        -      1       0
# ...

# %%
print(len(case_data))
print(len(case_data[case_data["ConfirmedIndianNational"]=="-"]))
print(len(case_data[case_data["ConfirmedForeignNational"]=="-"]))
# Out:
# 2919
# 2473
# 2473

# %%
case_data[case_data["ConfirmedForeignNational"]=="-"]["Date"].min()
# Out:
# Timestamp('2020-03-29 00:00:00')

# %%
case_data[case_data["ConfirmedForeignNational"]=="-"]["Date"].max()
# Out:
# Timestamp('2020-06-11 00:00:00')

# %%
case_data=case_data.drop(["ConfirmedIndianNational","ConfirmedForeignNational","Sno"],axis=1)

# %%
case_data=case_data.sort_values(["State/UnionTerritory","Date"]).reset_index(drop=True)

# %%
case_data.head(10)
# Out:
#         Date      Time         State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-03-26   6:00 PM  Andaman and Nicobar Islands      0       0          1
# 1 2020-03-27  10:00 AM  Andaman and Nicobar Islands      0       0          1
# 2 2020-03-28   6:00 PM  Andaman and Nicobar Islands      0       0          6
# 3 2020-03-29   7:30 PM  Andaman and Nicobar Islands      0       0          9
# 4 2020-03-30   9:30 PM  Andaman and Nicobar Islands      0       0          9
# 5 2020-03-31   8:30 PM  Andaman and Nicobar Islands      0       0         10
# 6 2020-04-01   7:30 PM  Andaman and Nicobar Islands      0       0         10
# 7 2020-04-02   6:00 PM  Andaman and Nicobar Islands      0       0         10
# 8 2020-04-03   6:00 PM  Andaman and Nicobar Islands      0       0         10
# 9 2020-04-04   6:00 PM  Andaman and Nicobar Islands      0       0         10

# %%
statewise_cases=case_data.groupby(["State/UnionTerritory"]).agg({"Cured":max,"Deaths":max,"Confirmed":max}).reset_index()

# %%
statewise_cases.head()
# Out:
#           State/UnionTerritory  Cured  Deaths  Confirmed
# 0  Andaman and Nicobar Islands     33       0         34
# 1               Andhra Pradesh   2899      78       5269
# 2            Arunachal Pradesh      2       0         57
# 3                        Assam   1249       4       3092
# 4                        Bihar   3071      33       5710

# %%
import numpy as np
import pandas as pd
statewise_cases.plot(x="State/UnionTerritory",y="Confirmed",kind="bar",figsize=(20,10))

# %%
statewise_cases=statewise_cases.sort_values(["Confirmed"]).reset_index(drop=True)

# %%
statewise_cases.plot(x="State/UnionTerritory",y="Confirmed",kind="bar",figsize=(20,10))

# %%
statewise_cases["Confirmed"].sum()
# Out:
# 286952

# %%
statewise_cases["active_cases"]=statewise_cases["Confirmed"]-statewise_cases["Cured"]-statewise_cases["Deaths"]

# %%
statewise_cases.head()
# Out:
#           State/UnionTerritory  Cured  Deaths  Confirmed  active_cases
# 0                  Daman & Diu      0       0          2             2
# 1                       Sikkim      0       0         13            13
# 2           Dadar Nagar Haveli      2       0         26            24
# 3  Andaman and Nicobar Islands     33       0         34             1
# 4                    Meghalaya     13       1         44            30

# %%
statewise_cases["confirmed_country_per"]=round((statewise_cases["Confirmed"]/statewise_cases["Confirmed"].sum())*100,2)

# %%
statewise_cases
# Out:
#                 State/UnionTerritory  Cured  Deaths  Confirmed  active_cases  \
# 0                        Daman & Diu      0       0          2             2
# 1                             Sikkim      0       0         13            13
# 2                 Dadar Nagar Haveli      2       0         26            24
# 3        Andaman and Nicobar Islands     33       0         34             1
# 4                          Meghalaya     13       1         44            30
# 5                  Arunachal Pradesh      2       0         57            55
# 6                         Unassigned      0       0         77            77
# 7                            Mizoram      1       0         93            92
# 8                             Ladakh     52       1        115            62
# 9                         Puducherry     53       1        127            73
# 10                          Nagaland     22       0        128           106
# ...

# %%
statewise_cases=statewise_cases.tail(8).reset_index(drop=True)

# %%
statewise_cases
# Out:
#   State/UnionTerritory  Cured  Deaths  Confirmed  active_cases  \
# 0          West Bengal   3779     432       9328          5117
# 1       Madhya Pradesh   6892     427      10049          2730
# 2            Rajasthan   8569     259      11600          2772
# 3        Uttar Pradesh   6871     321      11610          4418
# 4              Gujarat  14735    1347      21521          5439
# 5                Delhi  12245     984      32810         19581
# 6           Tamil Nadu  19333     326      36841         17182
# 7          Maharashtra  44517    3438      94041         46086
#
#    confirmed_country_per
# 0                   3.25
# 1                   3.50
# 2                   4.04
# 3                   4.05
# 4                   7.50
# 5                  11.43
# 6                  12.84
# 7                  32.77

# %%
statewise_cases["confirmed_country_per"].sum()
# Out:
# 79.38

# %%
statewise_cases.plot(x="State/UnionTerritory",y=["Cured","Deaths","Confirmed"],kind="bar",figsize=(20,10))

# %%
statewise_cases["cured_ratio"]=round((statewise_cases["Cured"]/statewise_cases["Confirmed"]*100),2)
statewise_cases["death_ratio"]=round((statewise_cases["Deaths"]/statewise_cases["Confirmed"]*100),2)
statewise_cases["active_cases_ratio"]=round((statewise_cases["active_cases"]/statewise_cases["Confirmed"]*100),2)

# %%
statewise_cases
# Out:
#   State/UnionTerritory  Cured  Deaths  Confirmed  active_cases  \
# 0          West Bengal   3779     432       9328          5117
# 1       Madhya Pradesh   6892     427      10049          2730
# 2            Rajasthan   8569     259      11600          2772
# 3        Uttar Pradesh   6871     321      11610          4418
# 4              Gujarat  14735    1347      21521          5439
# 5                Delhi  12245     984      32810         19581
# 6           Tamil Nadu  19333     326      36841         17182
# 7          Maharashtra  44517    3438      94041         46086
#
#    confirmed_country_per  cured_ratio  death_ratio  active_cases_ratio
# 0                   3.25        40.51         4.63               54.86
# 1                   3.50        68.58         4.25               27.17
# 2                   4.04        73.87         2.23               23.90
# 3                   4.05        59.18         2.76               38.05
# ...

# %%
statewise_cases.plot(x="State/UnionTerritory",y=["death_ratio","cured_ratio","active_cases_ratio"],kind="bar",stacked=True,figsize=(20,10),fontsize=15)

# %%
case_data.head()
# Out:
#         Date      Time         State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-03-26   6:00 PM  Andaman and Nicobar Islands      0       0          1
# 1 2020-03-27  10:00 AM  Andaman and Nicobar Islands      0       0          1
# 2 2020-03-28   6:00 PM  Andaman and Nicobar Islands      0       0          6
# 3 2020-03-29   7:30 PM  Andaman and Nicobar Islands      0       0          9
# 4 2020-03-30   9:30 PM  Andaman and Nicobar Islands      0       0          9

# %%
case_data["shift1"]=case_data["Confirmed"].shift(periods=1,fill_value=0)
case_data.head()
# Out:
#         Date      Time         State/UnionTerritory  Cured  Deaths  Confirmed  \
# 0 2020-03-26   6:00 PM  Andaman and Nicobar Islands      0       0          1
# 1 2020-03-27  10:00 AM  Andaman and Nicobar Islands      0       0          1
# 2 2020-03-28   6:00 PM  Andaman and Nicobar Islands      0       0          6
# 3 2020-03-29   7:30 PM  Andaman and Nicobar Islands      0       0          9
# 4 2020-03-30   9:30 PM  Andaman and Nicobar Islands      0       0          9
#
#    shift1
# 0       0
# 1       1
# 2       1
# 3       6
# 4       9

# %%
case_data["daily_cases"]=case_data["Confirmed"]-case_data["shift1"]
case_data
# Out:
#            Date      Time         State/UnionTerritory  Cured  Deaths  \
# 0    2020-03-26   6:00 PM  Andaman and Nicobar Islands      0       0
# 1    2020-03-27  10:00 AM  Andaman and Nicobar Islands      0       0
# 2    2020-03-28   6:00 PM  Andaman and Nicobar Islands      0       0
# 3    2020-03-29   7:30 PM  Andaman and Nicobar Islands      0       0
# 4    2020-03-30   9:30 PM  Andaman and Nicobar Islands      0       0
# ...         ...       ...                          ...    ...     ...
# 2914 2020-06-07   8:00 AM                  West Bengal   3119     383
# 2915 2020-06-08   8:00 AM                  West Bengal   3303     396
# 2916 2020-06-09   8:00 AM                  West Bengal   3465     405
# 2917 2020-06-10   8:00 AM                  West Bengal   3620     415
# 2918 2020-06-11   8:00 AM                  West Bengal   3779     432
#
#       Confirmed  shift1  daily_cases
# 0             1       0            1
# 1             1       1            0
# ...

# %%
case_data.drop(["shift1"],axis=1,inplace=True)
case_data
# Out:
#            Date      Time         State/UnionTerritory  Cured  Deaths  \
# 0    2020-03-26   6:00 PM  Andaman and Nicobar Islands      0       0
# 1    2020-03-27  10:00 AM  Andaman and Nicobar Islands      0       0
# 2    2020-03-28   6:00 PM  Andaman and Nicobar Islands      0       0
# 3    2020-03-29   7:30 PM  Andaman and Nicobar Islands      0       0
# 4    2020-03-30   9:30 PM  Andaman and Nicobar Islands      0       0
# ...         ...       ...                          ...    ...     ...
# 2914 2020-06-07   8:00 AM                  West Bengal   3119     383
# 2915 2020-06-08   8:00 AM                  West Bengal   3303     396
# 2916 2020-06-09   8:00 AM                  West Bengal   3465     405
# 2917 2020-06-10   8:00 AM                  West Bengal   3620     415
# 2918 2020-06-11   8:00 AM                  West Bengal   3779     432
#
#       Confirmed  daily_cases  week_num
# 0             1            1        13
# 1             1            0        13
# ...

# %%
case_data["week_num"]=case_data["Date"].dt.week
new1 = case_data.groupby('week_num').max().reset_index()
new1
# Out:
#     week_num       Date     Time State/UnionTerritory  Cured  Deaths  \
# 0          5 2020-02-02  6:00 PM               Kerala      0       0
# 1          6 2020-02-09  6:00 PM               Kerala      0       0
# 2          7 2020-02-16  6:00 PM               Kerala      0       0
# 3          8 2020-02-23  6:00 PM               Kerala      0       0
# 4          9 2020-03-01  6:00 PM               Kerala      0       0
# 5         10 2020-03-08  6:00 PM        Uttar Pradesh      3       0
# 6         11 2020-03-15  6:00 PM          Uttarakhand      5       1
# 7         12 2020-03-22  6:00 PM          West Bengal      9       2
# 8         13 2020-03-29  7:30 PM          West Bengal     25       6
# 9         14 2020-04-05  9:30 PM          West Bengal     49      24
# 10        15 2020-04-12  6:00 PM          West Bengal    208     127
# 11        16 2020-04-19  5:00 PM          West Bengal    365     211
# 12        17 2020-04-26  5:00 PM          West Bengal   1076     323
# ...

# %%
case = case_data[case_data['State/UnionTerritory'].isin(statewise_cases['State/UnionTerritory'])]
case
# Out:
#            Date     Time State/UnionTerritory  Cured  Deaths  Confirmed  \
# 625  2020-03-02  6:00 PM                Delhi      0       0          1
# 626  2020-03-03  6:00 PM                Delhi      0       0          1
# 627  2020-03-04  6:00 PM                Delhi      0       0          1
# 628  2020-03-05  6:00 PM                Delhi      0       0          2
# 629  2020-03-06  6:00 PM                Delhi      0       0          3
# ...         ...      ...                  ...    ...     ...        ...
# 2914 2020-06-07  8:00 AM          West Bengal   3119     383       7738
# 2915 2020-06-08  8:00 AM          West Bengal   3303     396       8187
# 2916 2020-06-09  8:00 AM          West Bengal   3465     405       8613
# 2917 2020-06-10  8:00 AM          West Bengal   3620     415       8985
# 2918 2020-06-11  8:00 AM          West Bengal   3779     432       9328
#
#       daily_cases  week_num
# 625            -1        10
# 626             0        10
# ...

# %%
case['State/UnionTerritory'].unique()
# Out:
# array(['Delhi', 'Gujarat', 'Madhya Pradesh', 'Maharashtra', 'Rajasthan',
#        'Tamil Nadu', 'Uttar Pradesh', 'West Bengal'], dtype=object)

# %%
case[case['State/UnionTerritory']=='West Bengal'].tail(10)
# Out:
#            Date     Time State/UnionTerritory  Cured  Deaths  Confirmed  \
# 2909 2020-06-02  8:00 AM          West Bengal   2306     325       5772
# 2910 2020-06-03  8:00 AM          West Bengal   2410     335       6168
# 2911 2020-06-04  8:00 AM          West Bengal   2580     345       6508
# 2912 2020-06-05  8:00 AM          West Bengal   2768     355       6876
# 2913 2020-06-06  8:00 AM          West Bengal   2912     366       7303
# 2914 2020-06-07  8:00 AM          West Bengal   3119     383       7738
# 2915 2020-06-08  8:00 AM          West Bengal   3303     396       8187
# 2916 2020-06-09  8:00 AM          West Bengal   3465     405       8613
# 2917 2020-06-10  8:00 AM          West Bengal   3620     415       8985
# 2918 2020-06-11  8:00 AM          West Bengal   3779     432       9328
#
#       daily_cases  week_num
# 2909          271        23
# 2910          396        23
# 2911          340        23
# 2912          368        23
# 2913          427        23
# ...

# %%
new_df = pd.pivot_table(case, values='Confirmed', index='Date',columns='State/UnionTerritory').reset_index()
new_df
# Out:
# State/UnionTerritory       Date    Delhi  Gujarat  Madhya Pradesh  \
# 0                    2020-03-02      1.0      NaN             NaN
# 1                    2020-03-03      1.0      NaN             NaN
# 2                    2020-03-04      1.0      NaN             NaN
# 3                    2020-03-05      2.0      NaN             NaN
# 4                    2020-03-06      3.0      NaN             NaN
# ..                          ...      ...      ...             ...
# 97                   2020-06-07  27654.0  19592.0          9228.0
# 98                   2020-06-08  27654.0  20070.0          9401.0
# 99                   2020-06-09  29943.0  20545.0          9638.0
# 100                  2020-06-10  31309.0  21014.0          9849.0
# 101                  2020-06-11  32810.0  21521.0         10049.0
#
# State/UnionTerritory  Maharashtra  Rajasthan  Tamil Nadu  Uttar Pradesh  \
# 0                             NaN        NaN         NaN            NaN
# ...

# %%
from datetime import date as dt
new_df['week_num']=new_df.Date.dt.week
new_df.tail(15)
# Out:
# State/UnionTerritory       Date    Delhi  Gujarat  Madhya Pradesh  \
# 87                   2020-05-28  15257.0  15195.0          7261.0
# 88                   2020-05-29  16281.0  15562.0          7453.0
# 89                   2020-05-30  17386.0  15934.0          7645.0
# 90                   2020-05-31  18549.0  16343.0          7891.0
# 91                   2020-06-01  19844.0  16779.0          8089.0
# 92                   2020-06-02  20834.0  17200.0          8283.0
# 93                   2020-06-03  22132.0  17617.0          8420.0
# 94                   2020-06-04  23645.0  18100.0          8588.0
# 95                   2020-06-05  25004.0  18584.0          8762.0
# 96                   2020-06-06  26334.0  19094.0          8996.0
# 97                   2020-06-07  27654.0  19592.0          9228.0
# 98                   2020-06-08  27654.0  20070.0          9401.0
# 99                   2020-06-09  29943.0  20545.0          9638.0
# ...

# %%
df_fin = new_df.groupby('week_num').max().reset_index()
df_fin
# Out:
# State/UnionTerritory  week_num       Date    Delhi  Gujarat  Madhya Pradesh  \
# 0                           10 2020-03-08      3.0      NaN             NaN
# 1                           11 2020-03-15      7.0      NaN             NaN
# 2                           12 2020-03-22     29.0     18.0             4.0
# 3                           13 2020-03-29     49.0     58.0            30.0
# 4                           14 2020-04-05    503.0    122.0           165.0
# 5                           15 2020-04-12   1069.0    432.0           564.0
# 6                           16 2020-04-19   1893.0   1604.0          1407.0
# 7                           17 2020-04-26   2625.0   3071.0          2096.0
# 8                           18 2020-05-03   4122.0   5055.0          2846.0
# 9                           19 2020-05-10   6542.0   7796.0          3614.0
# 10                          20 2020-05-17   9333.0  10988.0          4789.0
# ...

# %%
df_fin.drop('Date', axis=1, inplace=True)
df_fin
# Out:
# State/UnionTerritory  week_num    Delhi  Gujarat  Madhya Pradesh  Maharashtra  \
# 0                           10      3.0      NaN             NaN          NaN
# 1                           11      7.0      NaN             NaN         32.0
# 2                           12     29.0     18.0             4.0         67.0
# 3                           13     49.0     58.0            30.0        186.0
# 4                           14    503.0    122.0           165.0        490.0
# 5                           15   1069.0    432.0           564.0       1761.0
# 6                           16   1893.0   1604.0          1407.0       3651.0
# 7                           17   2625.0   3071.0          2096.0       7628.0
# 8                           18   4122.0   5055.0          2846.0      12296.0
# 9                           19   6542.0   7796.0          3614.0      20228.0
# 10                          20   9333.0  10988.0          4789.0      30706.0
# ...

# %%
cols = list(df_fin.columns)
cols.remove('week_num')

for col in cols:
    df_fin[col+'_d'] = round((df_fin[col] - df_fin[col].shift(1))/df_fin[col].shift(1) * 100,2)
df_fin
# Out:
# State/UnionTerritory  week_num    Delhi  Gujarat  Madhya Pradesh  Maharashtra  \
# 0                           10      3.0      NaN             NaN          NaN
# 1                           11      7.0      NaN             NaN         32.0
# 2                           12     29.0     18.0             4.0         67.0
# 3                           13     49.0     58.0            30.0        186.0
# 4                           14    503.0    122.0           165.0        490.0
# 5                           15   1069.0    432.0           564.0       1761.0
# 6                           16   1893.0   1604.0          1407.0       3651.0
# 7                           17   2625.0   3071.0          2096.0       7628.0
# 8                           18   4122.0   5055.0          2846.0      12296.0
# 9                           19   6542.0   7796.0          3614.0      20228.0
# 10                          20   9333.0  10988.0          4789.0      30706.0
# ...

# %%
df_fin.columns
# Out:
# Index(['week_num', 'Delhi', 'Gujarat', 'Madhya Pradesh', 'Maharashtra',
#        'Rajasthan', 'Tamil Nadu', 'Uttar Pradesh', 'West Bengal', 'Delhi_d',
#        'Gujarat_d', 'Madhya Pradesh_d', 'Maharashtra_d', 'Rajasthan_d',
#        'Tamil Nadu_d', 'Uttar Pradesh_d', 'West Bengal_d'],
#       dtype='object', name='State/UnionTerritory')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
col2 = ['Delhi_d','Gujarat_d', 'Madhya Pradesh_d', 'Maharashtra_d', 'Rajasthan_d',
       'Tamil Nadu_d', 'Uttar Pradesh_d', 'West Bengal_d']

fig, ax= plt.subplots(4, 2, figsize=[20,15])
counter=0

print(ax)

for j in range(len(ax)):
    for i in range(2):
        if j==4 & i==1:
            break
        else:
            ax[j][i] = sns.lineplot(x='week_num', y=col2[counter], data=df_fin, ax=ax[j][i])
            ax[j][i].set_xlabel('week_num')
            ax[j][i].set_ylabel(col2[counter])
            counter+=1
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000015F4597308>
# ...
